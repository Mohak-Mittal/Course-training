# %%
#regx
import re
text = "hi mohak this side and i am getting board and y no  is 9754819464 i am 24"
pattern = "\d{10}"
print(re.findall(pattern,text))
pattern = "\d{2}"
print(re.findall(pattern,text))
# Out:
# ['9754819464']
# ['97', '54', '81', '94', '64', '24']
