# %%
def b(a):
    def c():
        print("============")
        a()
        print("============")
    return c

@ b
def a():
    print("hello world")

a()
# Out:
# ...
# hello world
# ...

# %%
def fact(n):
    b = 1
    for i in range (1,n+1):
        b = b*i
    print(b)

fact(5)
# Out:
# 120
